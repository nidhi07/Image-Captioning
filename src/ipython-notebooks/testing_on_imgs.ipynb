# %%
from pickle import load
from numpy import argmax
from keras.preprocessing.sequence import pad_sequences
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.models import Model
from keras.models import load_model

# extract features from each photo in the directory
def extract_features(filename):
	# load the model
	model = VGG16()
	# re-structure the model
	model.layers.pop()
	model = Model(inputs=model.inputs, outputs=model.layers[-1].output)
	# load the photo
	image = load_img(filename, target_size=(224, 224))
	# convert the image pixels to a numpy array
	image = img_to_array(image)
	# reshape data for the model
	image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
	# prepare the image for the VGG model
	image = preprocess_input(image)
	# get features
	feature = model.predict(image, verbose=0)
	return feature

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad input
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
	return in_text

# load the tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))
# pre-define the max sequence length (from training)
max_length = 34
# load the model
model = load_model('model_1.h5')
# load and prepare the photograph
photo = extract_features('example.jpg')
# generate description
description = generate_desc(model, tokenizer, photo, max_length)
print(description)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-78cc9dcb612d> in <module>()
#      66 max_length = 34
#      67 # load the model
# ---> 68 model = load_model('model_1.h5')
#      69 # load and prepare the photograph
#      70 photo = extract_features('example.jpg')
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     258             raise ValueError('No model found in config file.')
#     259         model_config = json.loads(model_config.decode('utf-8'))
# --> 260         model = model_from_config(model_config, custom_objects=custom_objects)
#     261
#     262         # set weights
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/saving.py in model_from_config(config, custom_objects)
#     332                         '`Sequential.from_config(config)`?')
#     333     from ..layers import deserialize
# --> 334     return deserialize(config, custom_objects=custom_objects)
#     335
#     336
#
# /usr/local/lib/python3.5/dist-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#      53                                     module_objects=globs,
#      54                                     custom_objects=custom_objects,
# ---> 55                                     printable_module_name='layer')
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     143                     config['config'],
#     144                     custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 145                                         list(custom_objects.items())))
#     146             with CustomObjectScope(custom_objects):
#     147                 return cls.from_config(config['config'])
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/network.py in from_config(cls, config, custom_objects)
#    1025                 if layer in unprocessed_nodes:
#    1026                     for node_data in unprocessed_nodes.pop(layer):
# -> 1027                         process_node(layer, node_data)
#    1028
#    1029         name = config.get('name')
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/network.py in process_node(layer, node_data)
#     984             # and building the layer if needed.
#     985             if input_tensors:
# --> 986                 layer(unpack_singleton(input_tensors), **kwargs)
#     987
#     988         def process_layer(layer_data):
#
# /usr/local/lib/python3.5/dist-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     498
#     499         if initial_state is None and constants is None:
# --> 500             return super(RNN, self).__call__(inputs, **kwargs)
#     501
#     502         # If any of `initial_state` or `constants` are specified and are Keras
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# /usr/local/lib/python3.5/dist-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state)
#    2110                                       mask=mask,
#    2111                                       training=training,
# -> 2112                                       initial_state=initial_state)
#    2113
#    2114     @property
#
# /usr/local/lib/python3.5/dist-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state, constants)
#     607                                              mask=mask,
#     608                                              unroll=self.unroll,
# --> 609                                              input_length=timesteps)
#     610         if self.stateful:
#     611             updates = []
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/theano_backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length)
#    1427                 outputs_info=[initial_output] + initial_states,
#    1428                 non_sequences=constants,
# -> 1429                 go_backwards=go_backwards)
#    1430
#    1431             # deal with Theano API inconsistency
#
# /usr/local/lib/python3.5/dist-packages/theano/scan_module/scan.py in scan(fn, sequences, outputs_info, non_sequences, n_steps, truncate_gradient, go_backwards, mode, name, profile, allow_gc, strict, return_list)
#    1004     # might do not want to. Currently we are working on removing the
#    1005     # dependencies on sandbox code completeley.
# -> 1006     from theano import gpuarray
#    1007     if gpuarray.pygpu_activated:
#    1008         # very often we end up in this situation when we want to
#
# /usr/local/lib/python3.5/dist-packages/theano/gpuarray/__init__.py in <module>()
#      31                    reg_context, get_context, ContextNotDefined)
#      32 from .basic_ops import as_gpuarray_variable
# ---> 33 from . import fft, dnn, opt, extra_ops, multinomial, reduction, sort, rng_mrg, ctc
#      34
#      35
#
# /usr/local/lib/python3.5/dist-packages/theano/gpuarray/fft.py in <module>()
#      12
#      13 import theano.tensor.fft
# ---> 14 from .opt import register_opt, op_lifter, register_opt2
#      15
#      16 try:
#
# /usr/local/lib/python3.5/dist-packages/theano/gpuarray/opt.py in <module>()
#      83 from .opt_util import alpha_merge, output_merge, pad_dims, unpad_dims
#      84 from .reduction import GpuMaxAndArgmax
# ---> 85 from .linalg import (GpuCusolverSolve, MATRIX_STRUCTURES_SOLVE, GpuCholesky,
#      86                      cusolver_available, GpuMagmaMatrixInverse, gpu_svd,
#      87                      GpuMagmaCholesky, gpu_qr, GpuMagmaEigh,
#
# /usr/local/lib/python3.5/dist-packages/theano/gpuarray/linalg.py in <module>()
#       3 import warnings
#       4
# ----> 5 import pkg_resources
#       6 import numpy as np
#       7 from numpy.linalg.linalg import LinAlgError
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in <module>()
#    2925
#    2926
# -> 2927 @_call_aside
#    2928 def _initialize_master_working_set():
#    2929     """
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in _call_aside(f, *args, **kwargs)
#    2911 # from jaraco.functools 1.3
#    2912 def _call_aside(f, *args, **kwargs):
# -> 2913     f(*args, **kwargs)
#    2914     return f
#    2915
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in _initialize_master_working_set()
#    2950     # all distributions added to the working set in the future (e.g. by
#    2951     # calling ``require()``) will get activated as well.
# -> 2952     add_activation_listener(lambda dist: dist.activate())
#    2953     working_set.entries=[]
#    2954     # match order
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in subscribe(self, callback)
#     954         self.callbacks.append(callback)
#     955         for dist in self:
# --> 956             callback(dist)
#     957
#     958     def _added_new(self, dist):
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in <lambda>(dist)
#    2950     # all distributions added to the working set in the future (e.g. by
#    2951     # calling ``require()``) will get activated as well.
# -> 2952     add_activation_listener(lambda dist: dist.activate())
#    2953     working_set.entries=[]
#    2954     # match order
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in activate(self, path)
#    2513             for pkg in self._get_metadata('namespace_packages.txt'):
#    2514                 if pkg in sys.modules:
# -> 2515                     declare_namespace(pkg)
#    2516
#    2517     def egg_name(self):
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in declare_namespace(packageName)
#    2095             # Ensure all the parent's path items are reflected in the child,
#    2096             # if they apply
# -> 2097             _handle_ns(packageName, path_item)
#    2098
#    2099     finally:
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in _handle_ns(packageName, path_item)
#    2045         path.append(subpath)
#    2046         loader.load_module(packageName)
# -> 2047         _rebuild_mod_path(path, packageName, module)
#    2048     return subpath
#    2049
#
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py in _rebuild_mod_path(orig_path, package_name, module)
#    2064         return sys_path.index(_normalize_cached(os.sep.join(parts)))
#    2065
# -> 2066     orig_path.sort(key=position_in_sys_path)
#    2067     module.__path__[:] = [_normalize_cached(p) for p in orig_path]
#    2068
#
# AttributeError: '_NamespacePath' object has no attribute 'sort'
